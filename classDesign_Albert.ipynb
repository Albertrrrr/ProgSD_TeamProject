# %% [raw]
# Introduction to Vehicle Class
#
# 属性 Attributes
# ID （主键)     Int(10)         区分不同的单车
# bikeType      String          电动、自行车（建议用子类复写）
# price         float           价格（建议用子类复写）
# location      String          记录单车的当前位置
# status        String          表示单车的状态（可用，维修）
# isRented      bool            表示单车的租用状态（租用，可用）
# isLocked      bool            表示单车的锁车状态（上锁，未上锁）
# batteryStatus float(10)         记录电池的充电状态
# renter        int(10)         记录租用者的信息
#
# 方法 Methods
# init()                  初始化方法         创建单车对象时初始化属性，设置ID、位置、状态等初始值。
# lock()                  锁定单车           锁定单车
# unlock()                解锁单车           解锁单车
# rent()                  租用单车           将单车分配给租用者，记录租用开始时间，改变租用属性
# returnBike()            归还代车           将单车还回，记录租用结束时间和位置，计算租用费用
# reportMaintenance()     保修              报告单车需要维修，将状态设置为维修中
# completeMaintenance()   维修完成           维修完成后将单车状态设置为可用
# vehicleDetails()        详细信息           用list的方式返回 车辆id 价格 当前状态 电池状态
# save()                  存入数据库          存入数据库
# update()                更新数据库          更新数据库 完成上述功能
# delete()                删除数据            删除数据
#
# GET/SET方法
# getBikeType()
# getPrice()
# getLocation()
# getStatus()
# getIsRented()
# getIsLock()
# getBatteryStatus()
# getRenter()
#
# setID()
# setBikeType()
# setPrice()
# setLocation()
# setStatus()
# setIsRented()
# setIsLock()
# setBatteryStatus()
# setRenter()
#
# Introduction to Order Class
#
# 属性 Attributes
# orderID （主键)     Int(10)         订单唯一标识号，区分不同订单
# renter             Int(10)         与class customer进行耦合 拿到租用者的信息
# bike               Int(10)         与Class Vehicle进行耦合  拿到车的id
# startTime          String          订单租用开始世界
# endTime            String          订单租用结束时间
# startLocation      String          订单开始位置
# endLocation        String          订单结束位置
# createTime         String          订单创建时间
# finishTIme         String          订单关闭时间
# cost               float           总花费
# isPaid             bool            是否支付 1 0
# isFlag             bool            能否租车 1 0
# status             bool          表示订单的状态，如已完成、进行中 1 0
#
# 方法 Methods
# init()                  初始化方法        创建订单对象时初始化属性，设置订单号、租用者、单车、开始时间等。
# startRent()             开始租用          记录租用开始时间，设置订单状态为进行中, 耦合车进行车辆租借
# endRent()               结束租用          记录租用结束时间，计算租用费用，设置订单状态为已完成
# orderDetails()          订单详情          返回订单的详细信息，包括订单号、租用者、单车、开始时间、结束时间、费用等
# close()                 关闭订单          核查支付，改变是否支付状态
# cancelOrder()           取消订单          取消订单，设置状态为已取消
# save()                  存入数据库         存入数据库
# update()                更新数据库         更新数据库 完成上述功能
# delete()                删除数据            删除数据
#
# GET/SET方法
# getOrderID()
# getRenter()
# getBike()
# getStartTime()
# getEndTime()
# getStartLocation()
# getEndLocation()
# getCreateTime()
# getFinishTIme()
# getCost()
# getIsPaid()
# getStatus()
#
# setOrderID()
# setRenter()
# setBike()
# setStartTime()
# setEndTime()
# setStartLocation()
# setEndLocation()
# setCreateTime()
# setFinishTIme()
# setCost()
# etIsPaid()
# setStatus()
#
# 订单结束后 将所有信息传入数据库 供customer类进行调用 根据customer id 进行 查询检索
#
# Introduction to Customer Class
# 属性 Attributes
# userID （副键)      Int(10)         用户唯一标识号，区分不同的用户  1
# name               String          姓名   1
# password           String          密码   1
# email   （主键）     String          邮箱   1
# balance            float           余额    1
#
# rentalHistory      list            租用历史
# reportHistory      list            提交工单历史
#
# 方法 Methods
# init()                  初始化方法        创建用户对象时初始化属性，设置用户号、姓名、密码、邮箱等。 1
# topUpBalance()          充值             增加账户的余额
# add()                  存入数据库          存入数据库   1
# update()                更新数据库          更新数据库 完成上述功能  更改姓名 更改密码 更改邮箱     1
# delete()                删除数据            删除数据    1
#
# rentBike()              租用单车          耦合订单类、单车类，进行租用
# returnBike()            结束租用          耦合订单类、单车类，结束租用
# cancel()                取消订单          耦合订单类、单车类，进行取消
# report()                提交工单          耦合工单类，提交报告
# userDetails()           用户详情          用list的方式返回 用户id 姓名 密码 邮箱 余额
#
#
# GET/SET方法
# getUserID()
# getName()
# getPassword()
# getEmail()
# getBalance()
# getRentalHistory()
# getReportHistory()
#
# setUserID()
# setName()
# setPassword()
# setEmail()
# setBalance()
# setRentalHistory()
# setReportHistory()
#
# Introduction to Manager Class
# 属性 Attributes
# managerID （主键)   Int(10)         管理者唯一标识号，区分不同的管理者
# name               String          姓名
# password           String          密码
# email              String          邮箱
# level              String          职级
# reportHistory      list            留言历史
#
#
# 方法 Methods
# init()                  初始化方法        创建管理者对象时初始化属性，设置用户号、姓名、密码、邮箱、职级等。
# save()                  存入数据库          存入数据库
# update()                更新数据库          更新数据库 完成上述功能
# delete()                删除数据            删除数据
# 有关于数据的一些方法随后补充
#
#
# GET/SET方法
# getUserID()
# getName()
# getPassword()
# getEmail()
# getReportHistory()
#
# setUserID()
# setName()
# setPassword()
# setEmail()
# setReportHistory()
#
#
# Introduction to Operator Class
# 属性 Attributes
# operatorID （主键)   Int(10)        操作者唯一标识号，区分不同的管理者
# name               String          姓名
# password           String          密码
# email              String          邮箱
# level              String          职级
# reportHistory      list            留言历史
# isFixedList        list            需要维修列表
# reportMessage      String          留言
#
# 方法 Methods
# init()                  初始化方法       创建管理者对象时初始化属性，设置用户号、姓名、密码、邮箱、职级等。
# updatesLocation()       更新车子位置      更新位置 以达到track的效果
# moveVehicle()           移动车子位置      移动车子的停放区域
# repair()                修理车子         设置status为normal
# changeBattery()         更换电池          修改当前车子的batteryStatus
# report()                留言             留言
# save()                  存入数据库        存入数据库
# update()                更新数据库        更新数据库 完成上述功能
# delete()                删除数据            删除数据
#
# GET/SET方法
# getOperatorID()
# getName()
# getPassword()
# getEmail()
# getReportHistory()
# getlevel()
# getIsFixedList()
# getReportMessage()
#
# setOperatorID()
# setName()
# setPassword()
# setEmail()
# setReportHistory()
# setlevel()
# setIsFixedList()
# setReportMessage()
#
# Introduction to Report Class
# 属性 Attributes
# reID   （主键)      Int(10)         报告唯一标识号，区分不同的管理者
# authen             boolean         报告来源 0: customer 1:operator
# fromID             Int(10)         报告者唯一标识号
# message            String          报告主体
# date               String          报告时间
# status             String          当前状态   未处理 正在处理 已处理
#
# 方法 Methods
# save()                  存入数据库          存入数据库
# done()                  完成报告需求        完成报告需
# update()                更新数据库          更新数据库 完成上述功能
#
# GET/SET方法
# getReID()
# getAuthentication()
# getFromID()
# getMessage()
# getDate()
# getStatus()
#
# setReID()
# setAuthentication()
# setFromID()
# setMessage()
# setDate()
# setStatus()
